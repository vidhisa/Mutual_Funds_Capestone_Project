# %%
import os

# Define the folders we need
folders = [
    "data/raw",
    "data/processed",
    "notebooks",
    "sql",
    "dashboard",
    "reports"
]

# Create each folder if it doesn't already exist
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created folder: {folder}")
# Out:
# Created folder: data/raw
# Created folder: data/processed
# Created folder: notebooks
# Created folder: sql
# Created folder: dashboard
# Created folder: reports

# %%
# %%writefile requirements.txt
# pandas
# numpy
# matplotlib
# seaborn
# plotly
# sqlalchemy
# requests
# scipy
# jupyter
# Out:
# Writing requirements.txt

# %%
import os
import pandas as pd

# %%
#files_to_load = [
 #   "01_fund_master.csv",
  #  "02_nav_history.csv",
 #   "03_aum_by_fund_house.csv",
 #   "04_monthly_sip_inflows.csv",
  #  "05_category_inflows.csv",
  #  "06_industry_folio_count.csv",
 #   "07_scheme_performance.csv",
  #  "08_investor_transactions.csv",
 #   "09_portfolio_holdings.csv",
 #   "10_benchmark_indices.csv"

# %%
import os
os.getcwd()
# Out:
# 'C:\\Mutual_Fund_Capstone_Project'

# %%
df_fund_master = pd.read_csv("data/raw/01_fund_master.csv")
df_nav_history = pd.read_csv("data/raw/02_nav_history.csv")
df_aum_by_fund_house = pd.read_csv("data/raw/03_aum_by_fund_house.csv")
df_monthly_sip_inflows = pd.read_csv("data/raw/04_monthly_sip_inflows.csv")
df_category_inflows = pd.read_csv("data/raw/05_category_inflows.csv")
df_industry_folio_count = pd.read_csv("data/raw/06_industry_folio_count.csv")
df_scheme_performance = pd.read_csv("data/raw/07_scheme_performance.csv")
df_investor_transactions = pd.read_csv("data/raw/08_investor_transactions.csv")
df_portfolio_holdings = pd.read_csv("data/raw/09_portfolio_holdings.csv")
df_benchmark_indices = pd.read_csv("data/raw/10_benchmark_indices.csv")

# %%
df_fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
df_fund_master.shape
# Out:
# (40, 15)

# %%
df_fund_master.dtypes
# Out:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object

# %%
df_nav_history.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
df_nav_history.shape
# Out:
# (46000, 3)

# %%
df_nav_history.dtypes
# Out:
# amfi_code      int64
# date          object
# nav          float64
# dtype: object

# %%
df_aum_by_fund_house.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
df_aum_by_fund_house.shape
# Out:
# (90, 5)

# %%
df_aum_by_fund_house.dtypes
# Out:
# date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object

# %%
df_monthly_sip_inflows.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
df_monthly_sip_inflows.shape
# Out:
# (48, 6)

# %%
df_monthly_sip_inflows.dtypes
# Out:
# month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object

# %%
df_category_inflows.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
df_category_inflows.shape
# Out:
# (144, 3)

# %%
df_category_inflows.dtypes
# Out:
# month                object
# category             object
# net_inflow_crore    float64
# dtype: object

# %%
df_industry_folio_count.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
df_industry_folio_count.shape
# Out:
# (21, 6)

# %%
df_industry_folio_count.dtypes
# Out:
# month                   object
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object

# %%
df_scheme_performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
df_scheme_performance.shape
# Out:
# (40, 19)

# %%
df_scheme_performance.dtypes
# Out:
# amfi_code               int64
# scheme_name            object
# fund_house             object
# category               object
# plan                   object
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade             object
# dtype: object

# %%
df_investor_transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
df_investor_transactions.shape
# Out:
# (32778, 13)

# %%
df_investor_transactions.dtypes
# Out:
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object

# %%
df_portfolio_holdings.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
df_portfolio_holdings.shape
# Out:
# (322, 8)

# %%
df_portfolio_holdings.dtypes
# Out:
# amfi_code              int64
# stock_symbol          object
# stock_name            object
# sector                object
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date        object
# dtype: object

# %%
df_benchmark_indices.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
df_benchmark_indices.shape
# Out:
# (8050, 3)

# %%
df_benchmark_indices.dtypes
# Out:
# date            object
# index_name      object
# close_value    float64
# dtype: object

# %%
#Understand fund master: print unique,fund houses, categories,sub-categories, risk grades
df_fund_master.fund_house.unique()
# Out:
# array(['SBI Mutual Fund', 'HDFC Mutual Fund', 'ICICI Prudential MF',
#        'Nippon India MF', 'Kotak Mahindra MF', 'Axis Mutual Fund',
#        'Aditya Birla Sun Life MF', 'UTI Mutual Fund', 'Mirae Asset MF',
#        'DSP Mutual Fund'], dtype=object)

# %%
df_fund_master.category.unique()
# Out:
# array(['Equity', 'Debt'], dtype=object)

# %%
df_fund_master.sub_category.unique()
# Out:
# array(['Large Cap', 'Small Cap', 'Gilt', 'Mid Cap', 'Short Duration',
#        'Value', 'Liquid', 'Index/ETF', 'Flexi Cap', 'Index',
#        'Large & Mid Cap', 'ELSS'], dtype=object)

# %%
df_fund_master.risk_category.unique()
# Out:
# array(['Moderate', 'Very High', 'Low', 'High', 'Moderately High'],
#       dtype=object)

# %%
missing_codes = df_master[~df_master['scheme_code'].isin(nav_codes)]['scheme_code'].unique()

# %%
master_codes = df_fund_master['amfi_code'].unique()
nav_codes = df_nav_history['amfi_code'].unique()

# %%
master_codes
# Out:
# array([119551, 119552, 119598, 119599, 119120, 100016, 125497, 100033,
#        125498, 100025, 120503, 120504, 120505, 120506, 120507, 118632,
#        118633, 118634, 118635, 118636, 120841, 120842, 120843, 120844,
#        119092, 119093, 119094, 119095, 101206, 101207, 101208, 102885,
#        102886, 102887, 148567, 148568, 148569, 149322, 149323, 149324])

# %%
missing_codes = df_fund_master[~df_fund_master['amfi_code'].isin(nav_codes)]['amfi_code'].unique()

# %%
missing_codes
# Out:
# array([], dtype=int64)

# %% [markdown]
# Findings:  Total missing codes identified: 0 (array([], dtype=int64))
#
# 100% of the schemes listed in the master file map perfectly to the historical price records.
